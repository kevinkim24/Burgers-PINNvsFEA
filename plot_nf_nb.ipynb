# %%
import numpy as np
import matplotlib.pyplot as plt

def create_plot():
    fig,ax = plt.subplots(figsize=(8,5),dpi=300)
    ax.grid(color='white')
    ax.set_xscale("log")
    ax.set_yscale("log")
    #ax.set_facecolor("aliceblue")
    ax.set_facecolor('#e4eff5')
    ax.set_title("1D Burgers Equation Pareto Curve")
    ax.set_xlabel("Training time (s)")
    ax.set_ylabel("MSE")

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.tick_params(bottom = False,left = False)
    ax.tick_params(axis='x', which='minor', bottom=False, 
                   top=False, labelbottom=True) 
    ax.tick_params(axis='y', which='minor', right=False, 
                   left=False, labelleft=True) 
    
    return fig,ax

# %%
plt.rcParams['text.usetex'] = False

# %%
fig,ax = create_plot()

load = np.load('Data_diff_train/vanilla_times_mses_1500nf1nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 1500, B: 2',color='olivedrab',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_1500nf25nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 1500, B: 50',color='darkseagreen',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_1500nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 1500, B: 100',color='lightgreen',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_1500nf100nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 1500, B: 200',color='mediumaquamarine',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_1500nf200nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 1500, B: 400',color='steelblue',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_1500nf400nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 1500, B: 800',color='dodgerblue',marker='o')


ax.set_title("1D Burgers Equation--1500 Domain Samples")
###############################

# Comment: no obvious improvement for 50+. 2n_b is not enough for all n_f.

###############################

ax.legend()

# %%
fig,ax = create_plot()

load = np.load('Data_diff_train/vanilla_times_mses_5000nf1nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 5000, U: 2',color='olivedrab',marker='o',alpha=0.9)

load = np.load('Data_diff_train/vanilla_times_mses_5000nf25nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 5000, U: 50',color='darkseagreen',marker='o',alpha=0.9)

load = np.load('Data_diff_train/vanilla_times_mses_5000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 5000, U: 100',color='lightgreen',marker='o',alpha=0.9)

load = np.load('Data_diff_train/vanilla_times_mses_5000nf100nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 5000, B: 200',color='mediumaquamarine',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_5000nf200nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 5000, B: 400',color='steelblue',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_5000nf400nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 5000, B: 800',color='dodgerblue',marker='o',alpha=0.7)

ax.set_title("1D Burgers Equation--5000 Domain Samples")

###############################

# Comment: <=100 is better than 50. No obvious improvement after <= 100 for nf = 5000.

###############################


ax.legend()

# %%
fig,ax = create_plot()

load = np.load('Data_diff_train/vanilla_times_mses_10000nf1nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 10000, B: 2',color='olivedrab',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_10000nf25nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 10000, B: 50',color='darkseagreen',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_10000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 10000, B: 100',color='lightgreen',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_10000nf100nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 10000, B: 200',color='mediumaquamarine',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_10000nf200nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 10000, B: 400',color='steelblue',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_10000nf400nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 10000, B: 800',color='dodgerblue',marker='o')


###############################

# Comment: <=100 is better than 50. No obvious improvement after <= 100 for nf = 10000.

###############################


ax.legend()

# %%
fig,ax = create_plot()

load = np.load('Data_diff_train/vanilla_times_mses_15000nf1nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 15000, B: 2',color='olivedrab',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_15000nf25nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 15000, B: 50',color='darkseagreen',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_15000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 15000, B: 100',color='lightgreen',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_15000nf100nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 15000, B: 200',color='mediumaquamarine',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_15000nf200nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 15000, B: 400',color='steelblue',marker='o')

load = np.load('Data_diff_train/vanilla_times_mses_15000nf400nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 15000, B: 800',color='dodgerblue',marker='o')


###############################

# 2 nb is not enough obviously.
# Comment: VERY VISIBLE THAT <=100 is better than 50. No obvious improvement after <= 100 for nf = 15000.

###############################


ax.legend()

# %%
fig,ax = create_plot()

load = np.load('Data_diff_train/vanilla_times_mses_20000nf1nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 20000, U: 2',color='olivedrab',marker='o',alpha=0.9)

load = np.load('Data_diff_train/vanilla_times_mses_20000nf25nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
#ax.plot(times[time_inds],mses[time_inds],label='F: 20000, U: 50',color='darkseagreen',marker='o',alpha=0.9)

load = np.load('Data_diff_train/vanilla_times_mses_20000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 20000, U: 100',color='lightgreen',marker='o',alpha=0.9)

load = np.load('Data_diff_train/vanilla_times_mses_20000nf100nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 20000, U: 200',color='mediumaquamarine',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_20000nf200nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 20000, U: 400',color='steelblue',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_20000nf400nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 20000, U: 800',color='dodgerblue',marker='o',alpha=0.7)

ax.set_title("1D Burgers Equation--20000 Domain Samples")
###############################


# nb 2 is not enough.
# Comment: As nf increases, <=100 becomes increasingly better than 50. Maybe the ratio is important 
# (boundary data gets drowned out)
# No improvement after <= 100 for nf = 20000.

###############################


ax.legend()

# %%
fig,ax = create_plot()

load = np.load('Data_diff_train/vanilla_times_mses_1500nf25nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 1500, U: 100',color='olivedrab',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_5000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 5000, U: 100',color='darkseagreen',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_10000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 10000, U: 100',color='lightgreen',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_15000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 15000, U: 100',color='steelblue',marker='o',alpha=0.7)

load = np.load('Data_diff_train/vanilla_times_mses_20000nf50nb.npy')
times = load[0]
time_inds = np.argsort(times)
mses = load[1]
ax.plot(times[time_inds],mses[time_inds],label='F: 20000, U: 100',color='dodgerblue',marker='o',alpha=0.7)



ax.set_title("1D Burgers Equation")
###############################


# Just the best ones for each n_f. 
# Comment: 1500 not enough.

###############################


ax.legend()
